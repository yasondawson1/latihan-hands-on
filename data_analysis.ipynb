# %%
import pandas as pd
import numpy as np

dataset = pd.read_csv("clean_zomato_final.csv",error_bad_lines=False)
dataset.drop(dataset.columns[[0]], axis=1, inplace=True)
dataset.head()
# Out:
#                                              address  cost_for_two  \
# 0   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...         60000
# 1       Jl. Condet Raya No. 50, Kramat Jati, Jakarta        185000
# 2              Jl. Rawa Domba, Pondok Bambu, Jakarta        100000
# 3              Jl. Pertengahan 5, Cijantung, Jakarta         80000
# 4   Jl. Sunan Giri No. 3, Lantai 2, Rawamangun, J...        150000
#
#                              cuisines      locality  rating  \
# 0         ['Taiwanese', ' Beverages']        Cakung     4.1
# 1                         ['Arabian']   Kramat Jati     4.3
# 2                       ['Indonesia']  Pondok Bambu     4.3
# 3                       ['Indonesia']     Cijantung     4.1
# 4  ['Asia', ' Western', ' Indonesia']    Rawamangun     0.0
#
#                      rest_name           type  votes
# 0                Kamu Tea Cafe  Beverage Shop    127
# 1                        Ajwad    Quick Bites    289
# ...

# %%
dataset.shape
# Out:
# (1675, 8)

# %%
dataset['cuisines'] = dataset['cuisines'].str.replace("'", '')

# %%
dataset.head()
# Out:
#                                              address  cost_for_two  \
# 0   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...         60000
# 1       Jl. Condet Raya No. 50, Kramat Jati, Jakarta        185000
# 2              Jl. Rawa Domba, Pondok Bambu, Jakarta        100000
# 3              Jl. Pertengahan 5, Cijantung, Jakarta         80000
# 4   Jl. Sunan Giri No. 3, Lantai 2, Rawamangun, J...        150000
#
#                        cuisines      locality  rating  \
# 0       [Taiwanese,  Beverages]        Cakung     4.1
# 1                     [Arabian]   Kramat Jati     4.3
# 2                   [Indonesia]  Pondok Bambu     4.3
# 3                   [Indonesia]     Cijantung     4.1
# 4  [Asia,  Western,  Indonesia]    Rawamangun     0.0
#
#                      rest_name           type  votes
# 0                Kamu Tea Cafe  Beverage Shop    127
# 1                        Ajwad    Quick Bites    289
# 2                     MASALALU    Quick Bites    542
# ...

# %%
sorted_cuisine = [s.strip() for s in sorted_cuisine]
sorted_cuisine = [s.replace("'", '') for s in sorted_cuisine]
print(len(sorted_cuisine))
# Out:
# 137

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import matplotlib.pyplot as plt
y_pos = np.arange(len(sorted_cuisine))
perf = []
for cuisine in sorted_cuisine:
    count = 0
    for ori_cuisine in dataset['cuisines']:
        if cuisine in ori_cuisine:
            count += 1
    perf.append(count)
    
print(len(perf))
# Out:
# 137

# %%
dict_cuisine = dict(zip(sorted_cuisine, perf))
print(dict_cuisine)
df_cuisine = pd.DataFrame.from_dict(dict_cuisine, orient='index')
#print(df_cuisine)
df_cuisine = df_cuisine.sort_values(by=0, ascending=False)
df_cuisine.rename(columns={0:'Number of Restaurant'}, inplace=True)
df_cuisine = df_cuisine[:10]
print(df_cuisine)
# Out:
# {'Aceh': 11, 'American': 27, 'Arabian': 14, 'Asia': 65, 'Asian': 0, 'BBQ': 11, 'Bakery': 69, 'Bakmi': 67, 'Bakso': 61, 'Barat': 0, 'Barbekyu': 0, 'Batak': 11, 'Betawi': 28, 'Beverages': 121, 'Bubble Tea': 14, 'Burger': 17, 'Cafe': 65, 'Chinese': 72, 'Coffee': 265, 'Continental': 2, 'Desserts': 151, 'Dimsum': 11, 'European': 2, 'Fast Food': 74, 'Finger Food': 5, 'Grill': 6, 'Healthy Food': 6, 'Ice Cream': 26, 'Indian': 1, 'Indonesia': 427, 'Indonesian': 0, 'Itali': 46, 'Italian': 0, 'Japanese': 0, 'Jawa': 175, 'Jepang': 118, 'Juices': 17, 'Kalimantan': 2, 'Kopi': 0, 'Korean': 14, 'Makanan Cepat Saji': 0, 'Makanan Jalanan': 0, 'Martabak': 23, 'Medan': 3, 'Mediterranean': 1, 'Middle Eastern': 7, 'Minuman': 65, 'Padang': 20, 'Palembang': 14, 'Peranakan': 7, 'Ramen': 29, 'Satay': 36, 'Seafood': 30, 'Singaporean': 5, 'Snacks': 34, 'Soto': 54, 'Steak': 35, 'Street Food': 105, 'Sumatera': 2, 'Sunda': 35, 'Sushi': 28, 'Taiwanese': 9, 'Tea': 103, 'Thai': 26, 'Western': 103, 'Balinese': 7, 'Ban
# ...

# %%
ax = df_cuisine.plot.barh()

# %%
def check_distribution(attr_name):
    print (dataset[attr_name].value_counts())

# %%
dataset.head()
# Out:
#                                              address  cost_for_two  \
# 0   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...         60000
# 1       Jl. Condet Raya No. 50, Kramat Jati, Jakarta        185000
# 2              Jl. Rawa Domba, Pondok Bambu, Jakarta        100000
# 3              Jl. Pertengahan 5, Cijantung, Jakarta         80000
# 4   Jl. Sunan Giri No. 3, Lantai 2, Rawamangun, J...        150000
#
#                        cuisines      locality  rating  \
# 0       [Taiwanese,  Beverages]        Cakung     4.1
# 1                     [Arabian]   Kramat Jati     4.3
# 2                   [Indonesia]  Pondok Bambu     4.3
# 3                   [Indonesia]     Cijantung     4.1
# 4  [Asia,  Western,  Indonesia]    Rawamangun     0.0
#
#                      rest_name           type  votes
# 0                Kamu Tea Cafe  Beverage Shop    127
# 1                        Ajwad    Quick Bites    289
# 2                     MASALALU    Quick Bites    542
# ...

# %%
dataset.to_csv('clean_locality_zomato.csv')

# %%
#dataset1 = dataset
#dataset1['cuisines'] = dataset['cuisines'].agg(lambda x: ','.join(map(str, x)))
#dataset1.head()

# %%
#dataset1.to_csv('string_cuisines.csv')

# %%
dataset['locality'] = dataset['locality'].str.strip()
check_distribution('locality')
# Out:
# Cibubur                    296
# Jatinegara                 165
# Cakung                     153
# Pulo Gadung                122
# Kramat Jati                121
# Rawamangun                 100
# Pondok Bambu                78
# Cawang                      74
# Matraman                    73
# Duren Sawit                 73
# Klender                     72
# Kampung Melayu              70
# Cijantung                   55
# Pinang Ranti                51
# Kalimalang                  49
# Makasar                     41
# Taman Mini                  39
# Cipayung                    35
# Taman Kuliner Kayuputih      7
# Gandaria                     1
# Name: locality, dtype: int64

# %%
dataset.to_csv('clean_locality_zomato.csv')

# %%
check_distribution('type')
# Out:
# Quick Bites        767
# Food Court         193
# Casual Dining      168
# Kafe               160
# Beverage Shop      119
# Kios                86
# Bakery              56
# Toko Minuman        41
# Dessert Parlor      39
# Street Vendor       25
# Toko Kue & Roti     20
# Bar                  1
# Name: type, dtype: int64

# %%
dataset['type'].value_counts().plot(kind='bar')

# %%
dataset.groupby('locality')['cost_for_two'].mean().plot(kind='bar')
plt.gca().invert_xaxis()
plt.show()

# %%
requested_cuisine = 'Seafood'
sorted_cuisine.index(requested_cuisine)
# Out:
# 52

# %%
dataset.head()
# Out:
#                                              address  cost_for_two  \
# 0   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...         60000
# 1       Jl. Condet Raya No. 50, Kramat Jati, Jakarta        185000
# 2              Jl. Rawa Domba, Pondok Bambu, Jakarta        100000
# 3              Jl. Pertengahan 5, Cijantung, Jakarta         80000
# 4   Jl. Sunan Giri No. 3, Lantai 2, Rawamangun, J...        150000
#
#                        cuisines      locality  rating  \
# 0       [Taiwanese,  Beverages]        Cakung     4.1
# 1                     [Arabian]   Kramat Jati     4.3
# 2                   [Indonesia]  Pondok Bambu     4.3
# 3                   [Indonesia]     Cijantung     4.1
# 4  [Asia,  Western,  Indonesia]    Rawamangun     0.0
#
#                      rest_name           type  votes
# 0                Kamu Tea Cafe  Beverage Shop    127
# 1                        Ajwad    Quick Bites    289
# 2                     MASALALU    Quick Bites    542
# ...

# %%
locality = dataset['locality'].unique()
#print(locality)
perf1 = []


for local in locality:
    count = 0
    for i, cuisine in dataset['cuisines'].iteritems():    
        #if local in dataset['locality']:
        if requested_cuisine in dataset['cuisines'][i]:
            if dataset['locality'][i] == local:
                count += 1
    perf1.append(count)

dict_locality = dict(zip(locality, perf1))
df_locality = pd.DataFrame.from_dict(dict_locality, orient='index')
#print(df_cuisine)
df_locality = df_locality.sort_values(by=0, ascending=False)
df_locality.rename(columns={0:'Number of Restaurant'}, inplace=True)
df_locality = df_locality[:10]
print(df_locality)
ax = df_locality.plot.barh()
# Out:
#                 Number of Restaurant
# Cibubur                            9
# Cakung                             3
# Cijantung                          3
# Rawamangun                         2
# Kampung Melayu                     2
# Kramat Jati                        2
# Cawang                             1
# Makasar                            1
# Taman Mini                         1
# Duren Sawit                        1

# %%
prices = dataset['cost_for_two'].unique()
#print(locality)
perf2 = []
add_price = []

for price in prices:
    count = 0
    for i, cuisine in dataset['cuisines'].iteritems():    
        #if local in dataset['locality']:
        if requested_cuisine in dataset['cuisines'][i]:
            if dataset['cost_for_two'][i] == price:
                count += 1
    perf2.append(count)
dict_price = dict(zip(prices, perf2))
df_price = pd.DataFrame.from_dict(dict_price, orient='index')
#print(df_cuisine)
df_price = df_price.sort_values(by=0, ascending=False)
df_price.rename(columns={0:'Number of Restaurant'}, inplace=True)
df_price = df_price[:10]
print(df_price)
ax = df_price.plot.barh()
# Out:
#         Number of Restaurant
# 200000                    10
# 100000                     5
# 80000                      3
# 150000                     3
# 180000                     3
# 90000                      2
# 300000                     1
# 130000                     1
# 160000                     1
# 250000                     1

# %%
dataset.head()
# Out:
#                                              address  cost_for_two  \
# 0   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...         60000
# 1       Jl. Condet Raya No. 50, Kramat Jati, Jakarta        185000
# 2              Jl. Rawa Domba, Pondok Bambu, Jakarta        100000
# 3              Jl. Pertengahan 5, Cijantung, Jakarta         80000
# 4   Jl. Sunan Giri No. 3, Lantai 2, Rawamangun, J...        150000
#
#                        cuisines      locality  rating  \
# 0       [Taiwanese,  Beverages]        Cakung     4.1
# 1                     [Arabian]   Kramat Jati     4.3
# 2                   [Indonesia]  Pondok Bambu     4.3
# 3                   [Indonesia]     Cijantung     4.1
# 4  [Asia,  Western,  Indonesia]    Rawamangun     0.0
#
#                      rest_name           type  votes
# 0                Kamu Tea Cafe  Beverage Shop    127
# 1                        Ajwad    Quick Bites    289
# 2                     MASALALU    Quick Bites    542
# ...

# %%
dataset['rv_score'] = dataset['rating'] * dataset['votes']
dataset.head()
# Out:
#                                              address  cost_for_two  \
# 0   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...         60000
# 1       Jl. Condet Raya No. 50, Kramat Jati, Jakarta        185000
# 2              Jl. Rawa Domba, Pondok Bambu, Jakarta        100000
# 3              Jl. Pertengahan 5, Cijantung, Jakarta         80000
# 4   Jl. Sunan Giri No. 3, Lantai 2, Rawamangun, J...        150000
#
#                        cuisines      locality  rating  \
# 0       [Taiwanese,  Beverages]        Cakung     4.1
# 1                     [Arabian]   Kramat Jati     4.3
# 2                   [Indonesia]  Pondok Bambu     4.3
# 3                   [Indonesia]     Cijantung     4.1
# 4  [Asia,  Western,  Indonesia]    Rawamangun     0.0
#
#                      rest_name           type  votes  rv_score
# 0                Kamu Tea Cafe  Beverage Shop    127     520.7
# 1                        Ajwad    Quick Bites    289    1242.7
# ...

# %%
dataset['rv_score'].describe()
# Out:
# count    1675.000000
# mean       95.789970
# std       375.117683
# min         0.000000
# 25%         0.000000
# 50%        16.500000
# 75%        71.700000
# max      6368.300000
# Name: rv_score, dtype: float64

# %%
dataset['normalize'] = (dataset['rv_score'] - dataset['rv_score'].min()) / (dataset['rv_score'].max() - dataset['rv_score'].min())
dataset.head()
# Out:
#                                              address  cost_for_two  \
# 0   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...         60000
# 1       Jl. Condet Raya No. 50, Kramat Jati, Jakarta        185000
# 2              Jl. Rawa Domba, Pondok Bambu, Jakarta        100000
# 3              Jl. Pertengahan 5, Cijantung, Jakarta         80000
# 4   Jl. Sunan Giri No. 3, Lantai 2, Rawamangun, J...        150000
#
#                        cuisines      locality  rating  \
# 0       [Taiwanese,  Beverages]        Cakung     4.1
# 1                     [Arabian]   Kramat Jati     4.3
# 2                   [Indonesia]  Pondok Bambu     4.3
# 3                   [Indonesia]     Cijantung     4.1
# 4  [Asia,  Western,  Indonesia]    Rawamangun     0.0
#
#                      rest_name           type  votes  rv_score  normalize
# 0                Kamu Tea Cafe  Beverage Shop    127     520.7   0.081764
# 1                        Ajwad    Quick Bites    289    1242.7   0.195138
# ...

# %%
dataset['normalize'].describe()
# Out:
# count    1675.000000
# mean        0.015042
# std         0.058904
# min         0.000000
# 25%         0.000000
# 50%         0.002591
# 75%         0.011259
# max         1.000000
# Name: normalize, dtype: float64

# %%
import numpy as np 
#check_distribution('normalize')
dataset['normalize'] = dataset['normalize'].round(4)
dataset.head()
# Out:
#                                              address  cost_for_two  \
# 0   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...         60000
# 1       Jl. Condet Raya No. 50, Kramat Jati, Jakarta        185000
# 2              Jl. Rawa Domba, Pondok Bambu, Jakarta        100000
# 3              Jl. Pertengahan 5, Cijantung, Jakarta         80000
# 4   Jl. Sunan Giri No. 3, Lantai 2, Rawamangun, J...        150000
#
#                        cuisines      locality  rating  \
# 0       [Taiwanese,  Beverages]        Cakung     4.1
# 1                     [Arabian]   Kramat Jati     4.3
# 2                   [Indonesia]  Pondok Bambu     4.3
# 3                   [Indonesia]     Cijantung     4.1
# 4  [Asia,  Western,  Indonesia]    Rawamangun     0.0
#
#                      rest_name           type  votes  rv_score  normalize
# 0                Kamu Tea Cafe  Beverage Shop    127     520.7     0.0818
# 1                        Ajwad    Quick Bites    289    1242.7     0.1951
# ...

# %%
from matplotlib.image import imread
import pandas as pd
import seaborn as sns
from sklearn.datasets.samples_generator import (make_blobs,
                                                make_circles,
                                                make_moons)
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_samples, silhouette_score

# %matplotlib inline
sns.set_context('notebook')
plt.style.use('fivethirtyeight')
from warnings import filterwarnings
filterwarnings('ignore')

# Plot the data
plt.figure(figsize=(6, 6))
plt.scatter(dataset.iloc[:, 4], dataset.iloc[:, 7])
plt.xlabel('Rating')
plt.ylabel('Voters')
plt.title('Visualization of popularity');

# %%
X_std = StandardScaler().fit_transform(dataset[['rating','votes']])
kmeans = KMeans(n_clusters=5, random_state=0).fit(X_std)
print(kmeans.cluster_centers_)   
# Get the cluster labels
print(kmeans.labels_)
# Out:
# [[-1.1515391  -0.29220031]
#  [ 0.80201716 -0.06300383]
#  [ 1.52452333 14.584472  ]
#  [ 1.28784007  4.72537556]
#  [ 1.10012576  1.26015826]]
# [4 3 3 ... 0 0 0]

# %%
c1 = (-1.1515391, -0.29220031)
c2 = (0.80201716, -0.06300383)
c4 = (1.28784007, 4.72537556)
c5 = (1.52452333, 14.584472)
c3 = (1.10012576, 1.26015826)

# %%
plt.scatter(X_std[:, 0], X_std[:, 1])
    
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='x')
    
plt.title('Data points and cluster centroids')
plt.show()

# %%
def calculate_distance(centroid, X, Y):
    distances = []
        
    # Unpack the x and y coordinates of the centroid
    c_x, c_y = centroid
        
    # Iterate over the data points and calculate the distance using the           # given formula
    for x, y in list(zip(X, Y)):
        root_diff_x = (x - c_x) ** 2
        root_diff_y = (y - c_y) ** 2
        distance = np.sqrt(root_diff_x + root_diff_y)
        distances.append(distance)
        
    return distances

# %%
import numpy as np
# Calculate the distance and assign them to the DataFrame accordingly
dataset['C1_Distance'] = calculate_distance(c1, dataset.rating, dataset.votes)
dataset['C2_Distance'] = calculate_distance(c2, dataset.rating, dataset.votes)
dataset['C3_Distance'] = calculate_distance(c3, dataset.rating, dataset.votes)
dataset['C4_Distance'] = calculate_distance(c4, dataset.rating, dataset.votes)
dataset['C5_Distance'] = calculate_distance(c5, dataset.rating, dataset.votes)

# Preview the data
dataset.head()

#masukkan ke cluster terdekat nilainya
# Out:
#                                              address  cost_for_two  \
# 0   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...         60000
# 1       Jl. Condet Raya No. 50, Kramat Jati, Jakarta        185000
# 2              Jl. Rawa Domba, Pondok Bambu, Jakarta        100000
# 3              Jl. Pertengahan 5, Cijantung, Jakarta         80000
# 4   Jl. Sunan Giri No. 3, Lantai 2, Rawamangun, J...        150000
#
#                        cuisines      locality  rating  \
# 0       [Taiwanese,  Beverages]        Cakung     4.1
# 1                     [Arabian]   Kramat Jati     4.3
# 2                   [Indonesia]  Pondok Bambu     4.3
# 3                   [Indonesia]     Cijantung     4.1
# 4  [Asia,  Western,  Indonesia]    Rawamangun     0.0
#
#                      rest_name           type  votes  rv_score  normalize  \
# 0                Kamu Tea Cafe  Beverage Shop    127     520.7     0.0818
# 1                        Ajwad    Quick Bites    289    1242.7     0.1951
# ...

# %%
dataset['Popularity'] = dataset[['C1_Distance', 'C2_Distance', 'C3_Distance', 'C4_Distance', 'C5_Distance']].apply(np.argmin, axis =1)
    
# Map the centroids accordingly and rename them
dataset['Popularity'] = dataset['Popularity'].map({'C1_Distance': 'Unrated', 'C2_Distance': 'Low', 'C3_Distance': 'Average', 'C4_Distance': 'Good', 'C5_Distance': 'Excellent'})
    
# Get a preview of the data
dataset.head(10)
# Out:
#                                              address  cost_for_two  \
# 0   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...         60000
# 1       Jl. Condet Raya No. 50, Kramat Jati, Jakarta        185000
# 2              Jl. Rawa Domba, Pondok Bambu, Jakarta        100000
# 3              Jl. Pertengahan 5, Cijantung, Jakarta         80000
# 4   Jl. Sunan Giri No. 3, Lantai 2, Rawamangun, J...        150000
# 5        Jl. Matraman Raya No. 22, Matraman, Jakarta        450000
# 6        Jl. Matraman Raya No. 22, Matraman, Jakarta        450000
# 7   AEON Mall, Lantai Ground, Jl. Jakarta Garden ...        550000
# 8   AEON Mall, Lantai Ground, Jl. Jakarta Garden ...        550000
# 9   Trans Studio Mall Cibubur, Lantai 3, Jl. Alte...        200000
#
#                        cuisines      locality  rating  \
# 0       [Taiwanese,  Beverages]        Cakung     4.1
# 1                     [Arabian]   Kramat Jati     4.3
# 2                   [Indonesia]  Pondok Bambu     4.3
# ...

# %%
dataset_top = dataset[(dataset['normalize']>0.5)]
dataset_top.head(10)
# Out:
#                                               address  cost_for_two  \
# 7    AEON Mall, Lantai Ground, Jl. Jakarta Garden ...        550000
# 8    AEON Mall, Lantai Ground, Jl. Jakarta Garden ...        550000
# 15         Jl. Pemuda Kavling 30, Rawamangun, Jakarta        150000
# 16   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...        160000
# 17   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...        160000
# 27   AEON Mall, Lantai Ground, Jl. Jakarta Garden ...        300000
#
#              cuisines    locality  rating                rest_name  \
# 7      [Jepang,  BBQ]      Cakung     4.7  Gyu - Kaku Japanese BBQ
# 8      [Jepang,  BBQ]     Cibubur     4.7  Gyu - Kaku Japanese BBQ
# 15  [Mexican,  Itali]  Rawamangun     4.2              Quiznos Sub
# 16   [Jepang,  Ramen]      Cakung     4.3               Seirock-Ya
# 17   [Jepang,  Ramen]     Cibubur     4.3               Seirock-Ya
# 27           [Jepang]      Cakung     4.7     On-Yasai Shabu Shabu
#
# ...

# %%
dataset_top_affordable = dataset[(dataset['cost_for_two']<200000) & (dataset['normalize']>0.3)]
dataset_top_affordable.head(10)
# Out:
#                                               address  cost_for_two  \
# 2               Jl. Rawa Domba, Pondok Bambu, Jakarta        100000
# 12   Jl. Balai Pustaka Timur C 6 Rawamangun, Rawam...        190000
# 15         Jl. Pemuda Kavling 30, Rawamangun, Jakarta        150000
# 16   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...        160000
# 17   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...        160000
# 39             Jl. Balai Pustaka, Rawamangun, Jakarta         80000
#
#                              cuisines      locality  rating  \
# 2                         [Indonesia]  Pondok Bambu     4.3
# 12  [Indonesia,  Cafe,  Coffee,  Tea]    Rawamangun     3.9
# 15                  [Mexican,  Itali]    Rawamangun     4.2
# 16                   [Jepang,  Ramen]        Cakung     4.3
# 17                   [Jepang,  Ramen]       Cibubur     4.3
# 39           [Street Food,  Martabak]    Rawamangun     4.5
#
# ...

# %%
ax = dataset_top.plot.barh(x='rest_name', y='normalize', rot=0)

# %%
axs = dataset_top_affordable.plot.barh(x='rest_name', y='normalize', rot=0)

# %%
axs = dataset_top_affordable.plot.barh(x='rest_name', y='cost_for_two', rot=0)

# %%
dataset.head()
# Out:
#                                              address  cost_for_two  \
# 0   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...         60000
# 1       Jl. Condet Raya No. 50, Kramat Jati, Jakarta        185000
# 2              Jl. Rawa Domba, Pondok Bambu, Jakarta        100000
# 3              Jl. Pertengahan 5, Cijantung, Jakarta         80000
# 4   Jl. Sunan Giri No. 3, Lantai 2, Rawamangun, J...        150000
#
#                        cuisines      locality  rating  \
# 0       [Taiwanese,  Beverages]        Cakung     4.1
# 1                     [Arabian]   Kramat Jati     4.3
# 2                   [Indonesia]  Pondok Bambu     4.3
# 3                   [Indonesia]     Cijantung     4.1
# 4  [Asia,  Western,  Indonesia]    Rawamangun     0.0
#
#                      rest_name           type  votes  rv_score  normalize  \
# 0                Kamu Tea Cafe  Beverage Shop    127     520.7     0.0818
# 1                        Ajwad    Quick Bites    289    1242.7     0.1951
# ...

# %%
check_distribution('Popularity')
# Out:
# Low          708
# Good         494
# Average      453
# Excellent     20
# Name: Popularity, dtype: int64

# %%
dataset.head()
# Out:
#                                              address  cost_for_two  \
# 0   AEON Mall, Lantai 1, Jl. Jakarta Garden City,...         60000
# 1       Jl. Condet Raya No. 50, Kramat Jati, Jakarta        185000
# 2              Jl. Rawa Domba, Pondok Bambu, Jakarta        100000
# 3              Jl. Pertengahan 5, Cijantung, Jakarta         80000
# 4   Jl. Sunan Giri No. 3, Lantai 2, Rawamangun, J...        150000
#
#                        cuisines      locality  rating  \
# 0       [Taiwanese,  Beverages]        Cakung     4.1
# 1                     [Arabian]   Kramat Jati     4.3
# 2                   [Indonesia]  Pondok Bambu     4.3
# 3                   [Indonesia]     Cijantung     4.1
# 4  [Asia,  Western,  Indonesia]    Rawamangun     0.0
#
#                      rest_name           type  votes  rv_score  normalize  \
# 0                Kamu Tea Cafe  Beverage Shop    127     520.7     0.0818
# 1                        Ajwad    Quick Bites    289    1242.7     0.1951
# ...

# %%
#dataset1 = dataset
#dataset1['cuisines'] = dataset['cuisines'].agg(lambda x: ','.join(map(str, x)))
#dataset1.head()

# %%
dataset.to_csv('final_data.csv')
